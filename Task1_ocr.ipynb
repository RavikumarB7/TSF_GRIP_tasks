# %% [markdown]
# <a href="https://colab.research.google.com/github/RavikumarB7/TSF_GRIP_tasks/blob/main/Task1_ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Optical charecter recognition using python**

# %%
#Install the necessary dependencies
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.

# %%
# !pip install pytesseract

# %%
#Import the necessary packages
from PIL import Image
import pytesseract
import os
from google.colab.patches import cv2_imshow
import cv2

# %%
#Function to extract text from image
def recgn_char(image):
  img = Image.open(image)
  image_read = cv2.imread(image)
  cv2_imshow(image_read)
  text = pytesseract.image_to_string(img, lang ='eng')
  print(text)

# %%
recgn_char('/content/ocr_img_1.png')
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F19A6793438>
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.

# %%
recgn_char('/content/ocr_img_2.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=660x400 at 0x7F19A67A9860>
# Day after day, day after day, We stuck,
# nor breath nor motion; As idle as a
# painted ship Upon a painted ocean.
#
# -Samuel Taylor Coleridge:
#
# © owerespub

# %%
recgn_char('/content/ocr_img_3.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=400x266 at 0x7F19A67C2160>
# "The earth has music for
# those who listen."
#
# Shakespeare

# %%
recgn_char('/content/ocr_img_4.png')
# Out:
# <PIL.Image.Image image mode=RGB size=550x550 at 0x7F19A67C2358>
# The Road Not Taken
#
# Robert Frost, 1874 - 1963
#
# ‘Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# ‘To where it bent in the undergrowth;
#
# ‘Then took the other, as just as far,
# ‘And having perhaps the better claim,
# Because it was grassy and wanted wear;
# ‘Though as for that the passing there
# Had worn them really about the same,
#
# ‘And both that morning equally lay
# In leaves no step had trodden black.
# ‘Oh, Ikept the first for another day!
# ‘Yet knowing how way leads on to way,
# I doubted if I should ever come back.
#
# I shall be telling this with a sigh
# ‘Somewhere ages and ages hence:
# ‘Two roads diverged in a wood, and I~
# I took the one less traveled by,
#
# And that has made all the difference.
